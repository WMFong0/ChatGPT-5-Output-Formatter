# %% [markdown]
# <a href="https://colab.research.google.com/github/WMFong0/ChatGPT-5-Output-Formatter/blob/Google-Colab-Version/ChatGPT_5_Formatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Credit: Randomly0
def format_string(string: str = "") -> str:
  string = string.strip()
  splited_string = string.split(" ")
  cleaner_string = [item for item in splited_string if item]

  #Remove this section of code if you don't want to fix the capitalization error
  for i in range(len(cleaner_string)):
    cleaner_string[i] = cleaner_string[i].lower().capitalize()


  return " ".join(cleaner_string)


while True:

  str_input = str(input("Please input ChatGPT output below. This tool will remove any extra spaces from the output of GPT. \n\t"))
  print(f"\nHere is your output:\n\n\t{format_string(str_input)}\n\n")
# Out:
# Please input ChatGPT output below. This tool will remove any extra spaces from the output of GPT.
# 	Helllo Lol       ll
#
# Here is your output:
#
# 	Helllo Lol Ll
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-972427538.py in <cell line: 0>()
#      15 while True:
#      16
# ---> 17   str_input = str(input("Please input ChatGPT output below. This tool will remove any extra spaces from the output of GPT. \n\t"))
#      18   print(f"\nHere is your output:\n\n\t{format_string(str_input)}\n\n")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
# Credit: Randomly0
def format_string(string: str = "") -> str:
  string = string.strip()
  splited_string = string.split(" ")
  cleaner_string = [item for item in splited_string if item]

  #Remove this section of code if you don't want to fix the capitalization error
  for i in range(len(cleaner_string)):
    cleaner_string[i] = cleaner_string[i].lower().capitalize()


  return " ".join(cleaner_string)


str_input = "AB C      C D     D  E" # Paste your string inside the two "", the program will directly output the fixed text
print(f"{format_string(str_input)}")
# Out:
# Ab C C D D E
